# %%
warp('granma.jpg','granmaout.jpg')
# Out:
# #P1------P3
# |        |
# #P2------P4
# Selected points:
# [(616, 510), (382, 919), (1448, 534), (1450, 1033)]
# Destination points:
# [(0, 0), (0, 1499), (1999, 0), (1999, 1499)]
# Perspective transform matrix:
# [[ 1.1465278e+01  6.5595961e+00 -1.0408005e+04]
#  [-4.7661829e-01  1.6522768e+01 -8.1330146e+03]
#  [ 1.4428315e-03  3.2986440e-03  1.0000000e+00]]
